# %%
from gensim.models import word2vec # using tensorflow backend'
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import pandas as pd

# %%
fname = 'word2vec_skipgram_s100_c25_all.gensim'
w2v_model = word2vec.Word2Vec.load(fname)

# %%
v = w2v_model.wv['MAF']

# %%
vocab = w2v_model.wv.vocab

# %%
X = np.matrix(Xl)

# %%
X.shape
# Out:
# (8675, 100)

# %%
tsne = TSNE(n_components=2, random_state=42)
np.set_printoptions(suppress=True)
XX = model.fit_transform(X)

# %%
x = XX[:, 0]
x = x.reshape(-1)
x.shape
# Out:
# (8675,)

# %%
y = XX[:, 1]
y = y.reshape(-1)
y.shape
# Out:
# (8675,)

# %%
plt.figure(figsize=(15, 10))
plt.scatter(x, y)
plt.show()

# %%
codones = list(vocab.keys())

# %%
df = pd.DataFrame(XX)

# %%
df['codone'] = codones

# %%
df.head()
# Out:
#           0         1 codone
# 0  0.086625  3.738930    VNR
# 1  3.416830 -4.018082    SGS
# 2 -0.863672  3.004022    APW
# 3  0.743383  3.083894    HLT
# 4 -7.709858  2.979795    AEE

# %%
save_path = 'codone_tsne.csv'
df.to_csv(save_path)
