# %%
import pickle
import pandas as pd
from gensim.models import word2vec # using tensorflow backend'
import logging

# %%
with open('all_codones.pickle', 'rb') as handle:
    all_codones = pickle.load(handle)

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

skip_gram = 1  # skip-gram = 1, cbow = 0
# negative_sampling = 1
# hie_softmax = 1
num_features = 100  # Word vector dimensionality
context = 25  # Context window size
# downsampling = 0  # Downsample setting for frequent words
# min_word_count = 1  # Minimum word count
num_workers = 4 

model = word2vec.Word2Vec(all_codones, sg=skip_gram, negative=5, workers=num_workers, size=num_features)
# model.init_sims(replace=True)
# Out:
# 2017-08-01 11:09:52,198 : INFO : collecting all words and their counts
# 2017-08-01 11:09:52,199 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-08-01 11:09:52,587 : INFO : PROGRESS: at sentence #10000, processed 1560704 words, keeping 8015 word types
# 2017-08-01 11:09:52,987 : INFO : PROGRESS: at sentence #20000, processed 3076774 words, keeping 8103 word types
# 2017-08-01 11:09:53,416 : INFO : PROGRESS: at sentence #30000, processed 4664251 words, keeping 8139 word types
# 2017-08-01 11:09:53,817 : INFO : PROGRESS: at sentence #40000, processed 6158066 words, keeping 8149 word types
# 2017-08-01 11:09:54,211 : INFO : PROGRESS: at sentence #50000, processed 7623169 words, keeping 8174 word types
# 2017-08-01 11:09:54,680 : INFO : PROGRESS: at sentence #60000, processed 9360276 words, keeping 8212 word types
# 2017-08-01 11:09:54,964 : INFO : PROGRESS: at sentence #70000, processed 10409790 words, keeping 8233 word types
# ...

# %%
# model_name = 'word2vec_skipgram_s100_c25_all.gensim'
# # model_name = "skip-gram_ns_softmax_300features_10context_Pro"
# model.save(model_name)
# Out:
# 2017-08-01 12:36:00,993 : INFO : saving Word2Vec object under word2vec_skipgram_s100_c25_all.gensim, separately None
# 2017-08-01 12:36:00,994 : INFO : not storing attribute syn0norm
# 2017-08-01 12:36:00,995 : INFO : not storing attribute cum_table
# 2017-08-01 12:36:01,078 : INFO : saved word2vec_skipgram_s100_c25_all.gensim

# %%
print('done')
# Out:
# done
